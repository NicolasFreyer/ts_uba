# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
import io

# %% [markdown]
# 1. Serie con valores aleatorios

# %%
serie = np.random.randn(100)

plt.plot(serie)
plt.show()

# %% [markdown]
# 2. Plotear dataset

# %% [markdown]
# (1era columna de Gaming)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ed430f0-0091-45e2-a71c-72c7b5c85f91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ed430f0-0091-45e2-a71c-72c7b5c85f91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ds = pd.read_csv(io.BytesIO(uploaded['Gaming.csv']), sep=';')

# %%
type(ds['ArenaOfValor'][0])
# Out:
# numpy.float64

# %%
ds.head()
# Out:
#          Row Labels  ArenaOfValor
# 0   2020-05-25 18            1.65
# 1   2020-05-25 19            2.50
# 2   2020-05-25 20            1.35
# 3   2020-05-25 21            2.10
# 4   2020-05-25 22            0.98

# %%
plt.figure(figsize=(20,6))
x_list = ds['Row Labels'].tolist()
y_list = ds['ArenaOfValor'].tolist()
plt.plot(x_list, y_list)
locs, labels = plt.xticks()
new_locs = locs[::24]
new_labels = labels[::24]
plt.xticks(new_locs, new_labels)
plt.show()

# %% [markdown]
# 3. Descripción de las series

# %% [markdown]
# 3.1 En la anterior serie ploteada observamos el tráfico de datos debido al uso de un video juego, tomando datos cada una hora durante 10 días. Lo que podemos apreciar son ciclo diarios, pero además, dentro de los ciclos diarios podemos ver dentro de cada día otros subciclos ("pico-valle-pico") lo que seguramente tengo una frecuencia asociada. Observando los máximos dentro de 7 días (7 mayores picos de corrido) observamos una tendencia decreciente intrasemanal, que en caso de tener mas datos podríamos corroborar. La serie aparenta ser acotada, pero al igual que con lo anterior, nos faltarían datos para poder afirmarlo con mayor seguridad.

# %% [markdown]
# 3.2

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ad21f5f4-9145-498d-a8d4-b95215ce927c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad21f5f4-9145-498d-a8d4-b95215ce927c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ds = pd.read_csv(io.BytesIO(uploaded['airmiles.csv']))

# %%
ds.columns
# Out:
# Index(['Unnamed: 0', 'airmiles'], dtype='object')

# %%
plt.figure(figsize=(20,6))
plt.plot(ds['Unnamed: 0'], ds['airmiles'])
locs, labels = plt.xticks()
plt.show()

# %% [markdown]
# En la serie anterior podemos observar picos cada 12 instancias al igual que vayes de esos ciclos de 12 instancias (a 12 también). Esto evidencia un comportamiento estacional. Además observamos antes de la instancia 70 ( aprox) un crecimiento en la tendencia y ambien en la varianza a medida que avanzan las instancias. En la instancia 70 observamos una interveción en la serie, que se debe a un factor externo. A partir de esa instancia y hacia adelante se replica el comportamiento anterior: cíclico (al menos con un ciclo de 12 instancias pero también , posiblemente, con otro ciclo interno dentro de las 12; tal vez sea ruido en lo contrario), tendencia creciente de la media y también de la varianza ( se observa que la amplitud de los ciclos va aumentando)

# %% [markdown]
# 3.3

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-da0f0824-3161-4deb-9a6d-49660d9db1c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da0f0824-3161-4deb-9a6d-49660d9db1c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ds = pd.read_csv(io.BytesIO(uploaded['catfish.csv']))

# %%
ds.columns
# Out:
# Index(['Date', 'Total'], dtype='object')

# %%
plt.figure(figsize=(20,6))
plt.plot(ds.Date, ds['Total'])
locs, labels = plt.xticks()
new_locs = locs[::12]
new_labels = labels[::12]
plt.xticks(new_locs, new_labels)
plt.show()

# %% [markdown]
# En la serie anterior tenemos graficados datos de catfish entre 2012 y 1986 una vez por mes. Al igual que en las anteriores series, observamos el comportamiento cíclcio año a año. En este caso observamos que la media tiene un tendencia creciente hasta cierto punto (2003 aprox y luego decae. No observo el creciemiento en la varianza tan amarcado como en las anteriores series. Al igual que en las otras series, también hay alta posibilidad de tener unsa componenente cíclica intra anual.
